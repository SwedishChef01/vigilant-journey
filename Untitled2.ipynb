# %%
import gta_prices
import numpy as np
import pandas as pd

# %%
def donchian(prices, period):
    '''Calculate upper, lower, & middle Donchian lines.'''
    df = pd.DataFrame(prices)
    df['upr'] = prices.high.rolling(period).max().shift(periods=1)
    df['lwr'] = prices.low.rolling(period).min().shift(periods=1)
    df['mid'] = 0.5 * (df.upr + df.lwr)
    return df

# %%
exchange = 'LSE'
tidm = 'HSV'
p = {'p1': 48, 'p2': 24, 'p3': 12, 'p4': 6}

# %%
prices = gta_prices.weekly(exchange, tidm)

# %%
s = {}
for i, j in enumerate(p.values()):
    globals()[f'p{i + 1}'] = j
    s[f's{i + 1}'] = donchian(prices, j)

# %%
s.keys()
# Out:
# dict_keys(['s1', 's2', 's3', 's4'])

# %%
s['s4']
# Out:
#              open    high    low     close     upr    lwr     mid
# date
# 1994-01-07    NaN     NaN    NaN   0.33234     NaN    NaN     NaN
# 1994-01-14    NaN     NaN    NaN   0.33385     NaN    NaN     NaN
# 1994-01-21    NaN     NaN    NaN   0.33815     NaN    NaN     NaN
# 1994-01-28    NaN     NaN    NaN   0.34031     NaN    NaN     NaN
# 1994-02-04    NaN     NaN    NaN   0.34095     NaN    NaN     NaN
# ...           ...     ...    ...       ...     ...    ...     ...
# 2022-04-15  8.900   8.900  8.500   8.55000   9.390  5.790  7.5900
# 2022-04-22  8.750   9.855  8.350   9.80500   9.390  5.790  7.5900
# 2022-04-29  9.850  10.170  9.570   9.83000   9.855  6.435  8.1450
# 2022-05-06  9.790  10.020  9.565   9.90000  10.170  6.605  8.3875
# 2022-05-13  9.925  11.250  9.560  10.69000  10.170  8.350  9.2600
#
# [1480 rows x 7 columns]

# %%
prices
# Out:
#              open    high    low     close     upr    lwr     mid
# date
# 1994-01-07    NaN     NaN    NaN   0.33234     NaN    NaN     NaN
# 1994-01-14    NaN     NaN    NaN   0.33385     NaN    NaN     NaN
# 1994-01-21    NaN     NaN    NaN   0.33815     NaN    NaN     NaN
# 1994-01-28    NaN     NaN    NaN   0.34031     NaN    NaN     NaN
# 1994-02-04    NaN     NaN    NaN   0.34095     NaN    NaN     NaN
# ...           ...     ...    ...       ...     ...    ...     ...
# 2022-04-15  8.900   8.900  8.500   8.55000   9.390  5.790  7.5900
# 2022-04-22  8.750   9.855  8.350   9.80500   9.390  5.790  7.5900
# 2022-04-29  9.850  10.170  9.570   9.83000   9.855  6.435  8.1450
# 2022-05-06  9.790  10.020  9.565   9.90000  10.170  6.605  8.3875
# 2022-05-13  9.925  11.250  9.560  10.69000  10.170  8.350  9.2600
#
# [1480 rows x 7 columns]

# %%
# Revert to concatanating price and donchian lines to create or look into creating copy of dataframe.
